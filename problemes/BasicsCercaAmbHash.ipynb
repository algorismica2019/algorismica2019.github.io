# %% [markdown]
# <div id="capcalera">
# <p><a href="https://colab.research.google.com/github/algorismica2019/algorismica2019.github.io/blob/master/problemes/BasicsCercaAmbHash.ipynb"><img style="margin:-10px 10px 20px 0" width="150px" align="right" src="https://raw.githubusercontent.com/algorismica2019/algorismica2019.github.io/master/problemes/assets/colab-badge.png?raw=1" alt="Obrir a Colab" title="Obrir i executar a Google Colaboratory"></a></p>
# <p style="clear:both"><img align='left' width="300px" style="padding-right:10px;float=left" src="https://raw.githubusercontent.com/algorismica2019/algorismica2019.github.io/master/problemes/assets/al-khwarizmi.png">Aquest notebook forma part dels continguts teòrics dels problemes de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a> impartida per <em>Jordi Vitrià</em> i <em>Mireia Ribera</em></p>
#
# <p>Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>
#
# <p>Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>
#
# <p style="clear:both;text-align:center">&lt; <a href="CalculComplexitat.ipynb">Càlcul complexitat</a> | <a href="LListatProblemes.ipynb">LListat de problemes</a> | <a href="Els8Errors.ipynb">Els 8 errors</a> &gt; </p>
#
# </div>

# %% [markdown]
# # <span class="tema">( Basics Python )</span> Hash universal

# %% [markdown]
# Les solucions a aquests exercicis són al fitxer [SolucionsCadenes](BasicsCercaAmbHash-Solucio.ipynb)

# %% [markdown]
# Volem guardar emmagatzemar informació dels estudiants. Partim d'una classe amb 99 alumnes, i volem crear una estructura que ens permeti cercar un alumne ràpidament. Farem 1000 cerques d'un alumne concret.
#
# ### Conceptualització del problema
#
# - Quina estructura podem crear per tal que cada cerca tingui cost O(1)? (el problema no es pot resoldre amb una estructura pròpia de Python)

# %%
# la llista de NIUBs és la segÜent

llistaniubs=['niub18518012', 'niub18589763', 'niub18589776', 'niub16973034', 'niub19125491', 'niub18518486', 
             'niub18518330', 'niub18518500', 'niub16347854', 'niub18588533', 'niub18566891', 'niub16888180', 
             'niub18519741', 'niub18596201', 'niub18518114', 'niub18588572', 'niub16625902', 'niub14730841', 
             'niub16584633', 'niub18519702', 'niub18518511', 'niub18518450', 'niub18589754', 'niub18588522', 
             'niub18518425', 'niub16440881', 'niub18518051', 'niub16043701', 'niub18588114', 'niub16805093', 
             'niub18519763', 'niub16687712', 'niub18589710', 'niub14763863', 'niub18596304', 'niub18598894', 
             'niub18518006', 'niub18518442', 'niub18518091', 'niub16828450', 'niub18588511', 'niub18588232', 
             'niub16831426', 'niub18518346', 'niub11236310', 'niub18588120', 'niub18567770', 'niub10196663', 
             'niub19121165', 'niub16815441', 'niub18589726', 'niub18589794', 'niub18569595', 'niub16609841', 
             'niub18599174', 'niub18519794', 'niub18518136', 'niub16803506', 'niub18569091', 'niub10308215', 
             'niub16120940', 'niub16313033', 'niub16843842', 'niub18581933', 'niub18588595', 'niub18597724', 
             'niub18595521', 'niub16759784', 'niub18518383', 'niub18518464', 'niub16421613', 'niub16839025', 
             'niub18518324', 'niub16766465', 'niub16271220', 'niub16699055', 'niub18588184', 'niub16619210', 
             'niub18588544', 'niub18519780', 'niub18588170', 'niub18518065', 'niub18588162', 'niub18519735', 
             'niub18518040', 'niub18593112', 'niub18518305', 'niub18593525', 'niub18588581', 'niub18567304', 
             'niub18588136', 'niub18518490', 'niub19125804', 'niub18589735', 'niub18588566', 'niub16806162', 
             'niub18518475', 'niub16638516', 'niub16633574']

# els alumnes a buscar seran els següents:
import random
def llistaABuscar():
    abuscar=[]
    for i in range(0,1000):
        x=random.randint(0,98)
        abuscar.append(llistaniubs[x])
    return abuscar

abuscar=llistaABuscar()

print(abuscar)
# Out:
# ['niub18588232', 'niub18518450', 'niub18518450', 'niub10308215', 'niub18589794', 'niub16759784', 'niub19125804', 'niub18589776', 'niub16633574', 'niub16699055', 'niub16584633', 'niub16815441', 'niub18569595', 'niub18518475', 'niub16839025', 'niub16699055', 'niub18597724', 'niub18593525', 'niub18596304', 'niub18595521', 'niub16347854', 'niub18593112', 'niub18518040', 'niub16421613', 'niub18518012', 'niub18589754', 'niub16687712', 'niub18518511', 'niub11236310', 'niub18519741', 'niub18588533', 'niub16313033', 'niub18519763', 'niub14730841', 'niub16806162', 'niub16043701', 'niub18518464', 'niub18518006', 'niub16828450', 'niub18595521', 'niub18588533', 'niub18518091', 'niub18518511', 'niub19125491', 'niub18518490', 'niub16831426', 'niub18588533', 'niub18588120', 'niub18593112', 'niub18588162', 'niub18588595', 'niub18518383', 'niub18589763', 'niub18588232', 'niub18519741', 'niub18567304', 'niub16633574', 'niub18589726', 'niub16638516', 'niub18589763', 'niub18518500', 'niub18519735', 'niub18588114', 'niub18567770', 'niub18588136', 'niub16699055', 'niub18588162', 'niub18588170', 'niub16609841', 'niub16638516', 'niub11236310', 'niub18593525', 'niub18519780', 'niub18593525', 'niub18589763', 'niub18518450', 'niub18519735', 'niub18588581', 'niub18588232', 'niub18596201', 'niub19125491', 'niub18518136', 'niub19125491', 'niub16609841', 'niub16815441', 'niub18588232', 'niub18518425', 'niub16043701', 'niub18588184', 'niub18593112', 'niub18518136', 'niub10308215', 'niub14763863', 'niub16888180', 'niub16584633', 'niub18588581', 'niub16313033', 'niub18595521', 'niub18588232', 'niub14730841', 'niub18569595', 'niub16699055', 'niub18518425', 'niub18581933', 'niub16831426', 'niub16271220', 'niub16584633', 'niub18519735', 'niub18518475', 'niub18589710', 'niub18588522', 'niub18519741', 'niub18518442', 'niub16815441', 'niub18518091', 'niub18595521', 'niub18518346', 'niub16973034', 'niub18588170', 'niub16619210', 'niub18589710', 'niub16687712', 'niub16843842', 'niub18597724', 'niub18518442', 'niub18567304', 'niub18589710', 'niub11236310', 'niub18518136', 'niub19125804', 'niub18518006', 'niub18588232', 'niub18588120', 'niub18518091', 'niub18599174', 'niub16843842', 'niub19125804', 'niub18596304', 'niub18518012', 'niub18518464', 'niub18518012', 'niub19125804', 'niub18588533', 'niub18518490', 'niub18589735', 'niub18518346', 'niub18588566', 'niub18518500', 'niub18518464', 'niub14763863', 'niub18588533', 'niub18569595', 'niub16584633', 'niub18567304', 'niub18518136', 'niub18518065', 'niub10308215', 'niub18519794', 'niub18518442', 'niub18518500', 'niub18588572', 'niub16440881', 'niub18518006', 'niub18588581', 'niub18518346', 'niub10308215', 'niub18518324', 'niub18588522', 'niub18518450', 'niub18518305', 'niub19125491', 'niub18518006', 'niub16803506', 'niub18518486', 'niub10196663', 'niub18589763', 'niub18518006', 'niub18569595', 'niub18569091', 'niub16633574', 'niub18599174', 'niub16806162', 'niub18519702', 'niub18588162', 'niub18519794', 'niub16806162', 'niub18518464', 'niub18518464', 'niub18588120', 'niub16828450', 'niub18588533', 'niub18588566', 'niub18518114', 'niub16806162', 'niub18519735', 'niub18589710', 'niub10196663', 'niub18518383', 'niub16843842', 'niub18518486', 'niub18518475', 'niub18588136', 'niub18589776', 'niub16759784', 'niub18588544', 'niub16609841', 'niub16609841', 'niub10196663', 'niub18596304', 'niub18588581', 'niub16839025', 'niub18588232', 'niub18588114', 'niub18566891', 'niub16839025', 'niub16120940', 'niub18518330', 'niub10308215', 'niub18518442', 'niub18581933', 'niub16619210', 'niub18589726', 'niub18588114', 'niub18588566', 'niub16421613', 'niub16625902', 'niub16625902', 'niub18598894', 'niub18518450', 'niub18518425', 'niub18588511', 'niub18588136', 'niub18518511', 'niub18518324', 'niub18567770', 'niub18589726', 'niub19125491', 'niub19125491', 'niub16120940', 'niub18588511', 'niub16973034', 'niub18518486', 'niub19125491', 'niub16347854', 'niub16843842', 'niub19121165', 'niub16619210', 'niub18518383', 'niub10308215', 'niub18588595', ...

# %%
# Un cop fet l'algorisme el comparararem amb la cerca binària. 
# Usarem alguns dels algorismes que coneixem per cercar o per ordenar


import timeit

def recBinSearch(x, nums, low, high):
    """
    Algorisme bàsic de cerca binària recursiva
    :param x el nombre a trobar
    :param nums la llista de nums a trobar
    :param low l'índex més baix de la subllista on estem cercant ara
    :param high l'índex més alt de la subllista on estem cercant ara
    :return posició de x a nums o -1 si no s'ha trobar
    """
    if low > high:
        return -1
    mid = (low + high) // 2
    items = nums[mid]
    if items == x:
        return mid
    elif x < items:
        return recBinSearch(x, nums, low, mid-1)
    else:
        return recBinSearch(x, nums, mid+1, high)

def partition(A, first, last):
    """
    Aquesta funció tria el valor mig entre l'element inicial, final i mig 
    d'una llista i l'ubica al lloc que li correspondrà quan la llista està 
    ordenada, alhora deixa a la seva esquerra valors menors i a la dreta
    valors majors. Per tant altera A
    A més retorna la posició de la partició
    """
    mid = (first + last)//2  #ordenem A[first],A[mid],A[last]
    if A[first] > A [mid]: A[first], A[mid] = A[mid], A[first]
    if A[first] > A [last]: A[first], A[last] = A[last], A[first]
    if A[mid] > A[last]:   A[mid], A[last] = A[last], A[mid]  
    A[mid], A[first] = A[first], A[mid] #valor mig a l’inici
    pivot = first
    i = first + 1
    j = last
  
    while True:
        while i <= last and A[i] <= A[pivot]: i += 1
        while j >= first and A[j] > A[pivot]: j -= 1
        if i >= j: break
        else:
            A[i], A[j] = A[j], A[i] #intercanviem, fem avançar i j
    A[j], A[pivot] = A[pivot], A[j] #vector partit, pivot=j
    return j

def quick_sort(A):
    quick_sort_r(A, 0, len(A) - 1)

def quick_sort_r(A , first, last):
    if last > first:
        pivot = partition(A, first, last)
        quick_sort_r(A, first, pivot - 1)
        quick_sort_r(A, pivot + 1, last)
    
def cercaNostra(abuscar):
        pass
        return posicions

def cercaBinaria(abuscar):
        pass
        return posicions

# %%
# %timeit cercaNostra()
# Out:
# 3.33 ms ± 501 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit cercaBinaria()
# Out:
# 6.35 ms ± 703 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Executar aquesta cel.la per donar estil al notebook
from IPython.core.display import HTML
import requests
style=requests.get('https://raw.githubusercontent.com/MireiaUB/algorismica2019.github.io/patch-1/prova.css').text
HTML('<style>{}</style>'.format(style))
# Out:
# <style><style>
#
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Lora');
#
# /*   adapted from https://github.com/edwardtufte/et-book/blob/gh-pages/et-book.css */
#
# @charset "UTF-8";
#
# @font-face {
#   font-family: "et-book";
#   src: url("et-book/roman-line-figures.ttf") format("truetype");
#   font-weight: normal;
#   font-style: normal
# }
#
# @font-face {
#   font-family: "et-book";
#   src: url("et-book/display-italic-old-style-figures.ttf") format("truetype");
#   font-weight: normal;
#   font-style: italic
# }
#
# @font-face {
#   font-family: "et-book";
#   src: url("et-book/bold-line-figures.ttf") format("truetype");
#   font-weight: bold;
#   font-style: normal
# }
#
# @font-face {
#   font-family: "et-book-roman-old-style";
#   src: url("et-book/roman-old-style-figures.ttf") format("truetype");
#   font-weight: normal;
#   font-style: normal;
# }
#
# html {
#        font-size: 15px !important;
# }
#
# .tema, h1 span { font-size: 14pt;
# 	font-style: italic;
# 	font-weight: 100;}
#
# #capcalera {	font-family:Arial;
# 		font-size:12pt;
# 		background-color:#fff1f1;
# 		padding:5px;
# 		}
# #peu {	font-family:Arial;
# 	font-size:12pt;
# 	background-color:#fff1f1;
# 	padding:2px;
# 	line-height:1}
#
# .exercici {color:#a60d0d;
# 	   /* border-width:0 0 2px 2px !important;
# 	   border-style:solid !important;
# 	   border-color:#5e3333 !important; */ }
#
# .explicacio {}
#
# .avaluacio {}
#
#
# #notebook-container, .notebook_cell_list {
#        font-size: 1rem !important;
#        line-height: 1.5 !important;
#        width: 100%  !important;
#        margin-left: auto !important;
#        margin-right: auto !important;
#        padding-left: 12.5% !important;
#        font-family: et-book, Palatino, "Palatino Linotype", "Palatino LT STD", "Book Antiqua", Georgia, serif  !important;
#        background-color: #fffff8 !important;
#        color: #111 !important;
#        max-width: 1400px !important; }
#
#  .rendered .input_prompt {
# 	 min-width:0 !important; }
#
# .text_cell_render h1, .markdown h1 {
#      font-weight: 400;
#      font-style: normal;
#      margin-top: 0rem;
#      margin-bottom: 0rem;
#      font-size: 2rem; }
#
#  .text_cell_render h2 { font-style: italic;
#      font-weight: 400;
#      font-size: 1.5rem;
#      margin-top: 1.5rem;
#      margin-bottom: 1.5em; }
#
#  .text_cell_render h3 { font-style: italic;
#              font-weight: 400;
#              margin-top: 1rem;
#              margin-bottom: 1rem;
#              font-size: 1.2rem;
#              display: block; }
#
#  .text_cell_render h4 {
#     font-size: 1.1rem;
#     font-weight: 400;
#     margin: 1rem auto; }
#
# .rendered_html p {
# 	font-size: 1rem !important;
#     	margin-top: 1rem !important;;
#     	margin-bottom: 1rem !important;;
#     	padding-right: 0 !important;;
#     	vertical-align: baseline !important;; }
#
# .rendered_html blockquote { font-size: 1.1rem !important;}
#
# .rendered_html ol, ul { width: 75% !important;; }
#
# .rendered_html li { padding: 0.5rem 0 !important;; }
#
# .rendered_html table {
#   border-top: 2px solid #111 !important;
#   border-bottom: 2px solid #111 !important;
#   font-size: 0.8rem !important;
# }
#
# .rendered_html th {
#   border-bottom: 1px solid #111 !important;
# }
#
# .rendered_html a { text-decoration: none !important;
#          background: linear-gradient(#fffff8, #fffff8), linear-gradient(#fffff8, #fffff8), linear-gradient(#333, #333);
#          background-size: 0.05em 1px, 0.05em 1px, 1px 1px;
#          background-repeat: no-repeat, no-repeat, repeat-x;
#          text-shadow: 0.03em 0 #fffff8, -0.03em 0 #fffff8, 0 0.03em #fffff8, 0 -0.03em #fffff8, 0.06em 0 #fffff8, -0.06em 0 #fffff8, 0.09em 0 #fffff8, -0.09em 0 #fffff8, 0.12em 0 #fffff8, -0.12em 0 #fffff8, 0.15em 0 #fffff8, -0.15em 0 #fffff8;
#          background-position: 0% 93%, 100% 93%, 0% 93%; }
#
# .rendered_html a:link::selection { text-shadow: 0.03em 0 #b4d5fe, -0.03em 0 #b4d5fe, 0 0.03em #b4d5fe, 0 -0.03em #b4d5fe, 0.06em 0 #b4d5fe, -0.06em 0 #b4d5fe, 0.09em 0 #b4d5fe, -0.09em 0 #b4d5fe, 0.12em 0 #b4d5fe, -0.12em 0 #b4d5fe, 0.15em 0 #b4d5fe, -0.15em 0 #b4d5fe;
#                     background: #b4d5fe; }
#
# .rendered_html pre {
# 	border:1px solid #cccccc !important; }
#
# .rendered_html * code {
# 	font-size: 1rem !important;
#         line-height: 1.5 !important;
# 	font-family: Consolas, "Liberation Mono", Menlo, Courier, monospace !important;
# 	background-color: #fff !important }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     scale: 95,
#                         availableFonts: [],
#                         preferredFont:null,
#                         webFont: "TeX",
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 },
#                  "fast-preview": {
#                     "disabled": false
#                 }
#         });
# </script>
# </style>

# %% [markdown]
# <div id="peu">
# <p><a href="https://colab.research.google.com/github/algorismica2019/algorismica2019.github.io/blob/master/problemes/BasicsCercaAmbHash.ipynb"><img style="margin:-10px 10px 20px 0" width="150px" align="right" src="https://raw.githubusercontent.com/algorismica2019/algorismica2019.github.io/master/problemes/assets/colab-badge.png?raw=1" alt="Obrir a Colab" title="Obrir i executar a Google Colaboratory"></a></p>
# <p style="clear:both;text-align:center">&lt; <a href="CalculComplexitat.ipynb">Càlcul complexitat</a> | <a href="LListatProblemes.ipynb">LListat de problemes</a> | <a href="Els8Errors.ipynb">Els 8 errors</a> &gt; </p>
# </div>
