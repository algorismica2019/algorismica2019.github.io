# %% [markdown]
# <div id="capcalera">
# <p><a href="https://colab.research.google.com/github/algorismica2019/algorismica2019.github.io/blob/master/problemes/EdicionsDistancia1.ipynb"><img style="margin:-10px 10px 20px 0" width="150px" align="right" src="https://raw.githubusercontent.com/algorismica2019/algorismica2019.github.io/master/problemes/assets/colab-badge.png?raw=1" alt="Obrir a Colab" title="Obrir i executar a Google Colaboratory"></a></p>
# <p style="clear:both"><img align='left' width="300px" style="padding-right:10px;float=left" src="https://raw.githubusercontent.com/algorismica2019/algorismica2019.github.io/master/problemes/assets/al-khwarizmi.png">Aquest notebook forma part dels continguts teòrics dels problemes de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a> impartida per <em>Jordi Vitrià</em> i <em>Mireia Ribera</em></p>
#
# <p>Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>
#
# <p style="clear:both;text-align:center">&lt; <a href="Divisors.ipynb">Problema anterior</a> | <a href="LListatProblemes.ipynb">LListat de problemes</a> | <a href="FactorialMenor.ipynb">Problema següent</a> &gt; </p>
#
# </div>

# %% [markdown]
# # <span class="tema">( Python )</span> Generació de les edicions a distància 1 d'una paraula

# %% [markdown]
# Escriure un programa que generi **el conjunt** de totes les variacions d'edició (distància 1) d'una paraula.
#
# Suposem que:
# + Només usem les lletres ``abcdefghijklmnopqrstuvwxyz``
# + Les operacions d'edició són: eliminar una lletra (deletes) , transposar un parell de lletres (transpose), reemplaçar una lletra per una altra (replaces) i insertar una lletra de l'abecedari.
#
# Indicacions:
# + Cada un dels tipus d'edició es pot escriure com una *comprehension*.
# + Si la primera cosa que feu al principi és considerar totes les divisions possibles d'una paraula (per exemple, si per la paraula ```casa``` genereu ```('', 'casa'), ('c', 'asa'), ('ca', 'sa'), ('cas', 'a'), ('casa', '')```), us resultarà més fàcil generar les edicions a partir d'aquesta llista.

# %% [markdown]
# ### Conceptualització problema
#
# Aquest problema és força complex, per això detallem els passos a fer per arribar a la solució.
#
# 1. Crea una variable letters amb el valor 'abcdefghijklmnopqrstuvwxyz'
# 1. Crea una funció per fer les divisions inicials. Comprova que funciona. Reformula-la com a list comprehension i anomena-la splits. Ara pots recorrer aquesta llista anomenant L a la part esquerra, i R a la part dreta (for L,R in splits...)
# 1. Crea una list comprehension per als deletes
# 1. Crea una list comprehension per als transposes
# 1. Crea una list comprehension per als replaces
# 1. Crea una list comprehension per als inserts
# 1. Combina tots els resultats anteriors en un set per evitar repeticions
# 1. Posa un exemple de cadascuna de les operacions d'edició amb la paraula "casda" indicant quina operació és i on s'ha aplicat
# 1. Mostra els resultats de les list comprehensions anteriors en el cas edit('h')
#
# ### Implementació

# %%
def edit(word):
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes    = # escriu una list comprehension. Pots usar les tuples generades per splits
    transposes = # escriu una list comprehension. Pots usar les tuples generades per splits
    replaces   = # escriu una list comprehension. Pots usar les tuples generades per splits. Pots usar letters també
    inserts    = # escriu una list comprehension. Pots usar les tuples generades per splits. Pots usar letters també
    return set(deletes + transposes + replaces + inserts)

edit('h') # hauria de retornar ==>  {'','a','ah','b', 'bh', 'c', 'ch', 'd', 'dh', 'e', 'eh', 'f', 'fh', 
          #            'g', 'gh', 'h', 'ha', 'hb', 'hc', 'hd', 'he', 'hf', 'hg', 'hh',
          #            'hi', 'hj', 'hk', 'hl', 'hm', 'hn', 'ho', 'hp', 'hq', 'hr', 'hs',
          #           'ht', 'hu', 'hv', 'hw', 'hx', 'hy', 'hz', 'i', 'ih', 'j', 'jh',
          #           'k', 'kh', 'l', 'lh', 'm', 'mh', 'n', 'nh', 'o', 'oh', 'p', 'ph',
          #           'q', 'qh', 'r', 'rh', 's', 'sh', 't',  'th', 'u', 'uh', 'v', 'vh',
          #           'w', 'wh', 'x', 'xh', 'y', 'yh', 'z', 'zh'}>

# %% [markdown]
# pista1: <span style="color:white !important;">splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]</span>

# %%
# Per entendre millor el que retorna splits, fes una prova independent

def edit(word):
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     =  

edit("casa")

# %% [markdown]
# Fixat que en alguns casos L o R no tenen contingut.
#
# Si vols accedir a una part de L o R i comprovar que continguin alguna cosa pots fer servir la condició 'if L' o 'if R' respectivament

# %% [markdown]
# pista2: obre aquesta cel.la per veure el codi de la solució
# <!--
#     def edit(word):
#         letters    = 'abcdefghijklmnopqrstuvwxyz'
#         splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
#         deletes    = [L + R[1:]               for L, R in splits if R]
#         transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
#         replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
#         inserts    = [L + c + R               for L, R in splits for c in letters]
#         return set(deletes + transposes + replaces + inserts)
# -->

# %%
# Executar aquesta cel.la per donar estil al notebook
from IPython.core.display import HTML
import requests
style=requests.get('https://raw.githubusercontent.com/MireiaUB/algorismica2019.github.io/patch-1/prova.css').text
HTML('<style>{}</style>'.format(style))
# Out:
# <style><style>
#
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Lora');
#
# /*   adapted from https://github.com/edwardtufte/et-book/blob/gh-pages/et-book.css */
#
# @charset "UTF-8";
#
# @font-face {
#   font-family: "et-book";
#   src: url("et-book/roman-line-figures.ttf") format("truetype");
#   font-weight: normal;
#   font-style: normal
# }
#
# @font-face {
#   font-family: "et-book";
#   src: url("et-book/display-italic-old-style-figures.ttf") format("truetype");
#   font-weight: normal;
#   font-style: italic
# }
#
# @font-face {
#   font-family: "et-book";
#   src: url("et-book/bold-line-figures.ttf") format("truetype");
#   font-weight: bold;
#   font-style: normal
# }
#
# @font-face {
#   font-family: "et-book-roman-old-style";
#   src: url("et-book/roman-old-style-figures.ttf") format("truetype");
#   font-weight: normal;
#   font-style: normal;
# }
#
# html {
# ...

# %% [markdown]
# <div id="peu">
# <p><a href="https://colab.research.google.com/github/algorismica2019/algorismica2019.github.io/blob/master/problemes/EdicionsDistancia1.ipynb"><img style="margin:-10px 10px 20px 0" width="150px" align="right" src="https://raw.githubusercontent.com/algorismica2019/algorismica2019.github.io/master/problemes/assets/colab-badge.png?raw=1" alt="Obrir a Colab" title="Obrir i executar a Google Colaboratory"></a></p>
# <p style="clear:both;text-align:center">&lt; <a href="Divisors.ipynb">Problema anterior</a> | <a href="LListatProblemes.ipynb">LListat de problemes</a> | <a href="FactorialMenor.ipynb">Problema següent</a> &gt; </p>
# </div>
